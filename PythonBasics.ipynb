# %% [markdown]
# # Programming in Python
#
# Programming in Python is very similar to programming in R.
#
# However, there are a number of aspects of Python that differ wrom working in R and this page will highlight these.
#
# * Packages
# * Copying objects
# * Classes and Methods
# * Matrix operations
#
# ## Packages
